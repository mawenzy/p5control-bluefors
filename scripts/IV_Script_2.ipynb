# %% [markdown]
# IV Script - Nr. 2
#
# # HIV Measurement - 2023-08-28

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-08-29_HIV_23.5Ohm_0_keysight_source.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(100)
gw.femtos.set_amplification_B(10)

gw.R_ref.set_rref(100)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.025, 0.025, 201)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(1) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.source.set_output(False)
        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.source.set_amplitude(1.2)
        gw.source.set_period(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.source.set_output(True)
        gw.source.set_sweeping(True)
        sleep(120)
        m.stop()
        gw.source.set_output(False)
        
except:
    gw.source.set_output(False)
    gw.magnet.goto_zero()


gw.source.set_output(False)
gw.magnet.goto_zero()
# Out:
#   1%|          | 2/201 [06:20<10:30:29, 190.10s/it]

# %%
# Do 7 sweeps as before, and have long time to cooldown
# data_server_filename='.data/2023-08-28_HIV_23.5Ohm_1.hdf5'

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(100)
gw.femtos.set_amplification_B(10)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(1) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(1.2) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(120)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
# 100%|██████████| 241/241 [8:27:25<00:00, 126.33s/it]

# %%
# change ADwin averaging from 50 to 5 

##
# 1 crashes gui, also 5 elongates 10 sec sweep a bit, but not visible on the temperature
##

# data_server_filename='.data/2023-08-29_HIV_23.5Ohm_3_ADwin.hdf5'

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(5)
gw.femtos.set_amplification_A(100)
gw.femtos.set_amplification_B(10)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(1) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(1.2) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(120)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
# 100%|██████████| 241/241 [8:27:54<00:00, 126.45s/it]

# %% [markdown]
# # Repeat Measurement after one month of break - use avg = 50

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-09-29_HIV_25Ohm_0.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(100)
gw.femtos.set_amplification_B(10)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(1) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(1.2) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(120)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
# 100%|██████████| 241/241 [8:28:01<00:00, 126.48s/it]

# %% [markdown]
# # Measure 13.5kOhm HIV

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-02_HIV_13500Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(30) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(0.7) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(120)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
# 100%|██████████| 241/241 [10:24:08<00:00, 155.39s/it]

# %% [markdown]
# # Frequency Study with Antenna

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-04_fIV_HIV_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()
sleep(600)

gw.adwin.setAveraging(5)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(0)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)


gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:20<00:00, 78.77s/it]

# %% [markdown]
# # Repeat magnet study after having to break again

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-04_fIV_HIV_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    # gw.magnet.set_target_field(uH_range[0])
    # gw.magnet.ramp()
    # sleep(600)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        # sleep(30) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(0.7) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(120)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
# 100%|██████████| 241/241 [8:23:34<00:00, 125.37s/it]

# %% [markdown]
# # Frequency Study with Stripline

# %% [markdown]
# ### 0 dBm

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-06_MWIV_stripline_0dBm_13100Ohm_1.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()
# sleep(600)

gw.adwin.setAveraging(5)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(0)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)


gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [9:07:38<00:00, 84.04s/it]

# %% [markdown]
# ### -10 dBm

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-07_MWIV_stripline_-10dBm_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-10dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(0)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:16<00:00, 78.76s/it]

# %% [markdown]
# # Frequency study at -10, -5, -2 & +5 dBm

# %% [markdown]
# ### -10

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-07_MWIV_stripline_-10-5-2+5dBm_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-10dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-10)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:14<00:00, 78.76s/it]

# %% [markdown]
# ### -5

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-07_MWIV_stripline_-10-5-2+5dBm_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-5dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-5)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:12<00:00, 78.75s/it]

# %% [markdown]
# ### -2

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-07_MWIV_stripline_-10-5-2+5dBm_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-2dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-2)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:11<00:00, 78.75s/it]

# %% [markdown]
# ### +5

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-07_MWIV_stripline_-10-5-2+5dBm_13100Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_+5dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(1000)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(5)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:33:08<00:00, 78.74s/it]

# %% [markdown]
# # New contact @3000 Ohm - frequency study at -10 & -20 dBm - STRIPLINE

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-09_MWIV_stripline_-10-20_dBm_3000_Ohm_0.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-10dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-10)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:32:46<00:00, 78.69s/it]

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-09_MWIV_stripline_-10-20_dBm_3000_Ohm_0.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 391/391 [8:32:38<00:00, 78.67s/it]

# %% [markdown]
# # More detailed measurement
#
# same number of frequencies, but only 10-20 GHz,
# sweep twice as long for half the amplitude
#
# both axis have zoom of factor 4

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-10_MWIV_stripline_-20_dBm_3000_Ohm_zoom_2.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(10, 20, 401) #391

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(2)
        gw.adwin.setPeriod(100.123)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(110)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  76%|███████▌  | 305/401 [10:53:54<3:25:49, 128.64s/it]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:268, in SocketStream.read(self, count)
#     267 try:
# --> 268     buf = self.sock.recv(min(self.MAX_IO_CHUNK, count))
#     269 except socket.timeout:
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 31 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=59'>60</a> sleep(12)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=60'>61</a> m.start()
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=61'>62</a> gw.adwin.setSweeping(True)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:718, in Connection.sync_request(self, handler, *args)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
# --> 718 return _async_res.value
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\async_.py:106, in AsyncResult.value(self)
#     100 """Returns the result of the operation. If the result has not yet
#     101 arrived, accessing this property will wait for it. If the result does
#     102 not arrive before the expiry time elapses, :class:`AsyncResultTimeout`
#     103 is raised. If the returned result is an exception, it will be raised
#     104 here. Otherwise, the result is returned directly.
#     105 """
# --> 106 self.wait()
#     107 if self._is_exc:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\async_.py:51, in AsyncResult.wait(self)
#      47 while not (self._is_ready or self.expired):
#      48     # Serve the connection since we are not ready. Suppose
#      49     # the reply for our seq is served. The callback is this class
#      50     # so __call__ sets our obj and _is_ready to true.
# ---> 51     self._conn.serve(self._ttl)
#      53 # Check if we timed out before result was ready
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:438, in Connection.serve(self, timeout, wait_for_lock)
#     437     data = None  # Ensure data is initialized
# --> 438     data = self._channel.poll(timeout) and self._channel.recv()
#     439 except Exception as exc:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:55, in Channel.recv(self)
#      50 """Receives the next packet (or *frame*) from the underlying stream.
#      51 This method will block until the packet has been read completely
#      52
#      53 :returns: string of data
#      54 """
# ---> 55 header = self.stream.read(self.FRAME_HEADER.size)
#      56 length, compressed = self.FRAME_HEADER.unpack(header)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:277, in SocketStream.read(self, count)
#     276     self.close()
# --> 277     raise EOFError(ex)
#     278 if not buf:
#
# EOFError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:152, in BaseGateway.__getattr__(self, attr)
#     151 try:
# --> 152     return getattr(self._connection.root, attr)
#     153 except EOFError:
#     154     # the server might have disconnected - try reconnecting
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:751, in Connection.root(self)
#     750 if self._remote_root is None:
# --> 751     self._remote_root = self.sync_request(consts.HANDLE_GETROOT)
#     752 return self._remote_root
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:96, in ClosedFile.__getattr__(self, name)
#      95     raise AttributeError("stream has been closed")
# ---> 96 raise EOFError("stream has been closed")
#
# EOFError: stream has been closed
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:78, in BaseGateway.connect(self, config)
#      77 else:
# ---> 78     self._connection = rpyc.connect(
#      79         self.addr,
#      80         self.port,
#      81     )
#      83 if self.allow_callback:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\utils\factory.py:102, in connect(host, port, service, config, ipv6, keepalive)
#      90 """
#      91 creates a socket-connection to the given host and port
#      92
#    (...)
#     100 :returns: an RPyC connection
#     101 """
# --> 102 s = SocketStream.connect(host, port, ipv6=ipv6, keepalive=keepalive)
#     103 return connect_stream(s, service, config)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:174, in SocketStream.connect(cls, host, port, **kwargs)
#     173     kwargs["family"] = socket.AF_INET6
# --> 174 return cls(cls._connect(host, port, **kwargs))
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:126, in SocketStream._connect(cls, host, port, family, socktype, proto, timeout, nodelay, keepalive, attempts)
#     124 family, socktype, proto, _, sockaddr = socket.getaddrinfo(host, port, family,
#     125                                                           socktype, proto)[0]
# --> 126 s = socket_backoff_connect(family, socktype, proto, sockaddr, timeout, attempts)
#     127 try:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\lib\__init__.py:150, in socket_backoff_connect(family, socktype, proto, addr, timeout, attempts)
#     149 sock.settimeout(timeout)
# --> 150 sock.connect(addr)
#     151 connecting = False
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# BaseGatewayError                          Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 31 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=68'>69</a>         gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=69'>70</a> except:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=70'>71</a>     gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=71'>72</a>     gw.vna.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X41sZmlsZQ%3D%3D?line=73'>74</a> gw.adwin.setOutput(False)
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:155, in BaseGateway.__getattr__(self, attr)
#     152         return getattr(self._connection.root, attr)
#     153     except EOFError:
#     154         # the server might have disconnected - try reconnecting
# --> 155         self.reconnect()
#     156         return getattr(self._connection.root, attr)
#     157 # default python implementation
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:124, in BaseGateway.reconnect(self)
#     122 logger.info('reconnecting to "%s":%s', self.addr, self.port)
#     123 self.disconnect()
# --> 124 self.connect()
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:98, in BaseGateway.connect(self, config)
#      92 logger.debug(
#      93     'Gateway couldn\'t connect to server at "%s":%s - retrying...',
#      94     self.addr, self.port
#      95 )
#      97 if time.time() > timeout:
# ---> 98     raise BaseGatewayError(
#      99         f'Failed to connect to server at "{self.addr}:{self.port}"'
#     100     ) from exc
#     102 # limit the retrying rate
#     103 time.sleep(0.5)
#
# BaseGatewayError: Failed to connect to server at "localhost:42068"

# %% [markdown]
# Try again

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-10_MWIV_stripline_-20_dBm_3000_Ohm_quadruple_zoom_3.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(10, 20, 401) #391

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(2)
        gw.adwin.setPeriod(100.123)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(110)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  79%|███████▉  | 318/401 [11:17:07<2:56:44, 127.76s/it]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 33 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=59'>60</a> sleep(12)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=60'>61</a> m.start()
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=61'>62</a> gw.adwin.setSweeping(True)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:293, in SocketStream.write(self, data)
#     292 self.close()
# --> 293 raise EOFError(ex)
#
# EOFError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:152, in BaseGateway.__getattr__(self, attr)
#     151 try:
# --> 152     return getattr(self._connection.root, attr)
#     153 except EOFError:
#     154     # the server might have disconnected - try reconnecting
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:96, in ClosedFile.__getattr__(self, name)
#      95     raise AttributeError("stream has been closed")
# ---> 96 raise EOFError("stream has been closed")
#
# EOFError: stream has been closed
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:78, in BaseGateway.connect(self, config)
#      77 else:
# ---> 78     self._connection = rpyc.connect(
#      79         self.addr,
#      80         self.port,
#      81     )
#      83 if self.allow_callback:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\utils\factory.py:102, in connect(host, port, service, config, ipv6, keepalive)
#      90 """
#      91 creates a socket-connection to the given host and port
#      92
#    (...)
#     100 :returns: an RPyC connection
#     101 """
# --> 102 s = SocketStream.connect(host, port, ipv6=ipv6, keepalive=keepalive)
#     103 return connect_stream(s, service, config)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:174, in SocketStream.connect(cls, host, port, **kwargs)
#     173     kwargs["family"] = socket.AF_INET6
# --> 174 return cls(cls._connect(host, port, **kwargs))
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:126, in SocketStream._connect(cls, host, port, family, socktype, proto, timeout, nodelay, keepalive, attempts)
#     124 family, socktype, proto, _, sockaddr = socket.getaddrinfo(host, port, family,
#     125                                                           socktype, proto)[0]
# --> 126 s = socket_backoff_connect(family, socktype, proto, sockaddr, timeout, attempts)
#     127 try:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\lib\__init__.py:150, in socket_backoff_connect(family, socktype, proto, addr, timeout, attempts)
#     149 sock.settimeout(timeout)
# --> 150 sock.connect(addr)
#     151 connecting = False
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# BaseGatewayError                          Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 33 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=68'>69</a>         gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=69'>70</a> except:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=70'>71</a>     gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=71'>72</a>     gw.vna.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X43sZmlsZQ%3D%3D?line=73'>74</a> gw.adwin.setOutput(False)
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:155, in BaseGateway.__getattr__(self, attr)
#     152         return getattr(self._connection.root, attr)
#     153     except EOFError:
#     154         # the server might have disconnected - try reconnecting
# --> 155         self.reconnect()
#     156         return getattr(self._connection.root, attr)
#     157 # default python implementation
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:124, in BaseGateway.reconnect(self)
#     122 logger.info('reconnecting to "%s":%s', self.addr, self.port)
#     123 self.disconnect()
# --> 124 self.connect()
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:98, in BaseGateway.connect(self, config)
#      92 logger.debug(
#      93     'Gateway couldn\'t connect to server at "%s":%s - retrying...',
#      94     self.addr, self.port
#      95 )
#      97 if time.time() > timeout:
# ---> 98     raise BaseGatewayError(
#      99         f'Failed to connect to server at "{self.addr}:{self.port}"'
#     100     ) from exc
#     102 # limit the retrying rate
#     103 time.sleep(0.5)
#
# BaseGatewayError: Failed to connect to server at "localhost:42068"

# %% [markdown]
# # -20 dBm with antenna

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-09_MWIV_antenna_-20_dBm_3000_Ohm_1.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(1, 40, 391)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  81%|████████▏ | 318/391 [6:52:06<1:34:36, 77.76s/it]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 35 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=59'>60</a> sleep(12)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=60'>61</a> m.start()
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=61'>62</a> gw.adwin.setSweeping(True)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:293, in SocketStream.write(self, data)
#     292 self.close()
# --> 293 raise EOFError(ex)
#
# EOFError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:152, in BaseGateway.__getattr__(self, attr)
#     151 try:
# --> 152     return getattr(self._connection.root, attr)
#     153 except EOFError:
#     154     # the server might have disconnected - try reconnecting
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:96, in ClosedFile.__getattr__(self, name)
#      95     raise AttributeError("stream has been closed")
# ---> 96 raise EOFError("stream has been closed")
#
# EOFError: stream has been closed
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:78, in BaseGateway.connect(self, config)
#      77 else:
# ---> 78     self._connection = rpyc.connect(
#      79         self.addr,
#      80         self.port,
#      81     )
#      83 if self.allow_callback:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\utils\factory.py:102, in connect(host, port, service, config, ipv6, keepalive)
#      90 """
#      91 creates a socket-connection to the given host and port
#      92
#    (...)
#     100 :returns: an RPyC connection
#     101 """
# --> 102 s = SocketStream.connect(host, port, ipv6=ipv6, keepalive=keepalive)
#     103 return connect_stream(s, service, config)
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:174, in SocketStream.connect(cls, host, port, **kwargs)
#     173     kwargs["family"] = socket.AF_INET6
# --> 174 return cls(cls._connect(host, port, **kwargs))
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\core\stream.py:126, in SocketStream._connect(cls, host, port, family, socktype, proto, timeout, nodelay, keepalive, attempts)
#     124 family, socktype, proto, _, sockaddr = socket.getaddrinfo(host, port, family,
#     125                                                           socktype, proto)[0]
# --> 126 s = socket_backoff_connect(family, socktype, proto, sockaddr, timeout, attempts)
#     127 try:
#
# File c:\Users\BlueFors\AppData\Local\Programs\Python\Python311\Lib\site-packages\rpyc\lib\__init__.py:150, in socket_backoff_connect(family, socktype, proto, addr, timeout, attempts)
#     149 sock.settimeout(timeout)
# --> 150 sock.connect(addr)
#     151 connecting = False
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# BaseGatewayError                          Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 35 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=68'>69</a>         gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=69'>70</a> except:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=70'>71</a>     gw.adwin.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=71'>72</a>     gw.vna.setOutput(False)
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X46sZmlsZQ%3D%3D?line=73'>74</a> gw.adwin.setOutput(False)
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:155, in BaseGateway.__getattr__(self, attr)
#     152         return getattr(self._connection.root, attr)
#     153     except EOFError:
#     154         # the server might have disconnected - try reconnecting
# --> 155         self.reconnect()
#     156         return getattr(self._connection.root, attr)
#     157 # default python implementation
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:124, in BaseGateway.reconnect(self)
#     122 logger.info('reconnecting to "%s":%s', self.addr, self.port)
#     123 self.disconnect()
# --> 124 self.connect()
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:98, in BaseGateway.connect(self, config)
#      92 logger.debug(
#      93     'Gateway couldn\'t connect to server at "%s":%s - retrying...',
#      94     self.addr, self.port
#      95 )
#      97 if time.time() > timeout:
# ---> 98     raise BaseGatewayError(
#      99         f'Failed to connect to server at "{self.addr}:{self.port}"'
#     100     ) from exc
#     102 # limit the retrying rate
#     103 time.sleep(0.5)
#
# BaseGatewayError: Failed to connect to server at "localhost:42068"

# %% [markdown]
# # include 0 Hz

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-12_MWIV_antenna_-20_dBm_3000_Ohm_2.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(0, 25, 251)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  54%|█████▍    | 136/251 [2:56:07<2:28:57, 77.72s/it]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-12_MWIV_antenna_-20_dBm_3000_Ohm_3.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(0, 25, 251)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 251/251 [5:25:03<00:00, 77.70s/it]

# %% [markdown]
# -30 dBm

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-14_MWIV_antenna_-30_dBm_3000_Ohm_0.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-30dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(0, 25, 251)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-30)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 251/251 [5:29:05<00:00, 78.67s/it]

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-15_MWIV_stripline_-30_dBm_3000_Ohm_0.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-30dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(0, 25, 251)

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-30)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(4)
        gw.adwin.setPeriod(49.654)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
# 100%|██████████| 251/251 [5:29:24<00:00, 78.74s/it]

# %% [markdown]
# # Try zoom again

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-15-10_MWIV_stripline_-20_dBm_3000_Ohm_quadruple_zoom_4.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(10, 20, 401) #391

try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(2)
        gw.adwin.setPeriod(100.123)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(110)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  20%|█▉        | 79/401 [2:49:17<11:30:30, 128.67s/it]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-15-10_MWIV_stripline_-20_dBm_3000_Ohm_quadruple_zoom_6.hdf5')

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'frequency_at_-20dBm'
offset_name = 'offset'
sweep_name = 'sweep'

gw.magnet.goto_zero()

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

nu_range = np.linspace(10, 20, 401) #391

try:
    nu_zero = 0
    fname_zero = f'nu={nu_zero:.3f}GHz'
    gw.vna.setPower(-20)
    gw.vna.setTSweepFrequency(nu_zero*1e9)
    gw.vna.setOutput(True)
    # do IV sweep  
    gw.adwin.setSweeping(False)
    gw.adwin.setOutput(False)
    gw.adwin.setAmplitude(0)
    gw.adwin.setLocking(False)
    gw.adwin.setLockinAmplitude(0)
    gw.adwin.setLockinFrequency(73.3)

    m = gw.measure(f"{name}/{fname_zero}/{offset_name}")
    sleep(.5)
    m.start()
    sleep(5)
    m.stop()
    gw.adwin.setAmplitude(1)
    gw.adwin.setPeriod(50.123)

    m = gw.measure(f"{name}/{fname_zero}/{sweep_name}")
    sleep(12)
    m.start()
    gw.adwin.setSweeping(True)
    gw.adwin.setOutput(True)
    sleep(60)
    m.stop()
    
    gw.adwin.setAmplitude(0)
    gw.adwin.setSweeping(False)
    gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)


try:
    for i, nu in enumerate(tqdm(nu_range)):

        fname = f'nu={nu:.3f}GHz'

        gw.vna.setPower(-20)
        gw.vna.setTSweepFrequency(nu*1e9)
        gw.vna.setOutput(True)

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{fname}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(5)
        m.stop()

        gw.adwin.setAmplitude(1)
        gw.adwin.setPeriod(50.123)

        m = gw.measure(f"{name}/{fname}/{sweep_name}")

        sleep(12)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(60)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.vna.setOutput(False)

gw.adwin.setOutput(False)
gw.vna.setOutput(False)
# Out:
#  72%|███████▏  | 289/401 [6:19:36<2:27:06, 78.81s/it]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:268, in SocketStream.read(self, count)
#     267 try:
# --> 268     buf = self.sock.recv(min(self.MAX_IO_CHUNK, count))
#     269 except socket.timeout:
#
# ConnectionResetError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 44 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=87'>88</a> sleep(.5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=88'>89</a> m.start()
#      <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=89'>90</a> sleep(5)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\netref.py:148, in BaseNetref.__getattribute__(self, name)
#     147 else:
# --> 148     return syncreq(self, consts.HANDLE_GETATTR, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\netref.py:63, in syncreq(proxy, handler, *args)
#      62 conn = object.__getattribute__(proxy, "____conn__")
# ---> 63 return conn.sync_request(handler, proxy, *args)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:718, in Connection.sync_request(self, handler, *args)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
# --> 718 return _async_res.value
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\async_.py:106, in AsyncResult.value(self)
#     100 """Returns the result of the operation. If the result has not yet
#     101 arrived, accessing this property will wait for it. If the result does
#     102 not arrive before the expiry time elapses, :class:`AsyncResultTimeout`
#     103 is raised. If the returned result is an exception, it will be raised
#     104 here. Otherwise, the result is returned directly.
#     105 """
# --> 106 self.wait()
#     107 if self._is_exc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\async_.py:51, in AsyncResult.wait(self)
#      47 while not (self._is_ready or self.expired):
#      48     # Serve the connection since we are not ready. Suppose
#      49     # the reply for our seq is served. The callback is this class
#      50     # so __call__ sets our obj and _is_ready to true.
# ---> 51     self._conn.serve(self._ttl)
#      53 # Check if we timed out before result was ready
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:438, in Connection.serve(self, timeout, wait_for_lock)
#     437     data = None  # Ensure data is initialized
# --> 438     data = self._channel.poll(timeout) and self._channel.recv()
#     439 except Exception as exc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\channel.py:55, in Channel.recv(self)
#      50 """Receives the next packet (or *frame*) from the underlying stream.
#      51 This method will block until the packet has been read completely
#      52
#      53 :returns: string of data
#      54 """
# ---> 55 header = self.stream.read(self.FRAME_HEADER.size)
#      56 length, compressed = self.FRAME_HEADER.unpack(header)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:277, in SocketStream.read(self, count)
#     276     self.close()
# --> 277     raise EOFError(ex)
#     278 if not buf:
#
# EOFError: [WinError 10054] Eine vorhandene Verbindung wurde vom Remotehost geschlossen
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:152, in BaseGateway.__getattr__(self, attr)
#     151 try:
# --> 152     return getattr(self._connection.root, attr)
#     153 except EOFError:
#     154     # the server might have disconnected - try reconnecting
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:751, in Connection.root(self)
#     750 if self._remote_root is None:
# --> 751     self._remote_root = self.sync_request(consts.HANDLE_GETROOT)
#     752 return self._remote_root
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:715, in Connection.sync_request(self, handler, *args)
#     714 timeout = self._config["sync_request_timeout"]
# --> 715 _async_res = self.async_request(handler, *args, timeout=timeout)
#     716 # _async_res is an instance of AsyncResult, the value property invokes Connection.serve via AsyncResult.wait
#     717 # So, the _recvlock can be acquired multiple times by the owning thread and warrants the use of RLock
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:742, in Connection.async_request(self, handler, *args, **kwargs)
#     741 res = AsyncResult(self)
# --> 742 self._async_request(handler, args, res)
#     743 if timeout is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:724, in Connection._async_request(self, handler, args, callback)
#     723 try:
# --> 724     self._send(consts.MSG_REQUEST, seq, (handler, self._box(args)))
#     725 except Exception:
#     726     # TODO: review test_remote_exception, logging exceptions show attempt to write on closed stream
#     727     # depending on the case, the MSG_REQUEST may or may not have been sent completely
#     728     # so, pop the callback and raise to keep response integrity is consistent
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\protocol.py:298, in Connection._send(self, msg, seq, args)
#     297     data = self._send_queue.pop(0)
# --> 298     self._channel.send(data)
#     299 finally:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\channel.py:78, in Channel.send(self, data)
#      76 if self.FRAME_HEADER.size + data_size + flush_size <= self.stream.MAX_IO_CHUNK:
#      77     # avoid overhead from socket writes requiring GIL to be held
# ---> 78     self.stream.write(header + data + self.FLUSHER)
#      79 else:
#      80     # Data larger than 64KB, the extra writes are negligible
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:288, in SocketStream.write(self, data)
#     287 while data:
# --> 288     count = self.sock.send(data[:self.MAX_IO_CHUNK])
#     289     data = data[count:]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:96, in ClosedFile.__getattr__(self, name)
#      95     raise AttributeError("stream has been closed")
# ---> 96 raise EOFError("stream has been closed")
#
# EOFError: stream has been closed
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\Documents\p5control\p5control\gateway\basegw.py:78, in BaseGateway.connect(self, config)
#      77 else:
# ---> 78     self._connection = rpyc.connect(
#      79         self.addr,
#      80         self.port,
#      81     )
#      83 if self.allow_callback:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\utils\factory.py:102, in connect(host, port, service, config, ipv6, keepalive)
#      90 """
#      91 creates a socket-connection to the given host and port
#      92
#    (...)
#     100 :returns: an RPyC connection
#     101 """
# --> 102 s = SocketStream.connect(host, port, ipv6=ipv6, keepalive=keepalive)
#     103 return connect_stream(s, service, config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:174, in SocketStream.connect(cls, host, port, **kwargs)
#     173     kwargs["family"] = socket.AF_INET6
# --> 174 return cls(cls._connect(host, port, **kwargs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\core\stream.py:126, in SocketStream._connect(cls, host, port, family, socktype, proto, timeout, nodelay, keepalive, attempts)
#     124 family, socktype, proto, _, sockaddr = socket.getaddrinfo(host, port, family,
#     125                                                           socktype, proto)[0]
# --> 126 s = socket_backoff_connect(family, socktype, proto, sockaddr, timeout, attempts)
#     127 try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rpyc\lib\__init__.py:150, in socket_backoff_connect(family, socktype, proto, addr, timeout, attempts)
#     149 sock.settimeout(timeout)
# --> 150 sock.connect(addr)
#     151 connecting = False
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# BaseGatewayError                          Traceback (most recent call last)
# c:\Users\BlueFors\Documents\p5control-bluefors\IV Script copy.ipynb Cell 44 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=106'>107</a>         gw.adwin.setOutput(False)
#     <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=107'>108</a> except:
# --> <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=108'>109</a>     gw.adwin.setOutput(False)
#     <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=109'>110</a>     gw.vna.setOutput(False)
#     <a href='vscode-notebook-cell:/c%3A/Users/BlueFors/Documents/p5control-bluefors/IV%20Script%20copy.ipynb#X61sZmlsZQ%3D%3D?line=111'>112</a> gw.adwin.setOutput(False)
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:155, in BaseGateway.__getattr__(self, attr)
#     152         return getattr(self._connection.root, attr)
#     153     except EOFError:
#     154         # the server might have disconnected - try reconnecting
# --> 155         self.reconnect()
#     156         return getattr(self._connection.root, attr)
#     157 # default python implementation
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:124, in BaseGateway.reconnect(self)
#     122 logger.info('reconnecting to "%s":%s', self.addr, self.port)
#     123 self.disconnect()
# --> 124 self.connect()
#
# File ~\Documents\p5control\p5control\gateway\basegw.py:98, in BaseGateway.connect(self, config)
#      92 logger.debug(
#      93     'Gateway couldn\'t connect to server at "%s":%s - retrying...',
#      94     self.addr, self.port
#      95 )
#      97 if time.time() > timeout:
# ---> 98     raise BaseGatewayError(
#      99         f'Failed to connect to server at "{self.addr}:{self.port}"'
#     100     ) from exc
#     102 # limit the retrying rate
#     103 time.sleep(0.5)
#
# BaseGatewayError: Failed to connect to server at "localhost:42068"

# %% [markdown]
# # Magnet Study for 3 kOhm

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-16_HIV_3000Ohm_0.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    gw.magnet.set_target_field(uH_range[0])
    gw.magnet.ramp()
    sleep(600)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(30) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(2) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(30)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
#  73%|███████▎  | 177/241 [3:12:35<1:09:45, 65.40s/it]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# again

# %%
# inserv = InstrumentServer(data_server_filename='.data/2023-10-16_HIV_3000Ohm_1.hdf5')
# Don't forget to switch to sample temperature

from p5control import InstrumentGateway, DataGateway
from time import sleep

import numpy as np
from tqdm import tqdm

gw = InstrumentGateway()
dgw = DataGateway()

gw.connect()
dgw.connect()

name = 'critical field'
offset_name = 'offset'
sweep_name = 'sweep'

gw.adwin.setAveraging(50)
gw.femtos.set_amplification_A(1000)
gw.femtos.set_amplification_B(100)

gw.adwin.setLocking(False)
gw.adwin.setLockinAmplitude(0)
gw.adwin.setLockinFrequency(73.3)

gw.magnet.set_rate(0)

try:
    uH_range = np.linspace(-0.03, 0.03, 241)
    gw.magnet.set_target_field(uH_range[0])
    gw.magnet.ramp()
    sleep(600)
    for i, uH_soll in enumerate(tqdm(uH_range)):

        field_name = f'uH={uH_soll*1000:+.2f}mT'
        gw.magnet.set_target_field(uH_soll)
        gw.magnet.ramp()
        sleep(30) # sleep(20) # NEW: don't sleep, just skip first two sweeps 

        # do IV sweep  
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
        gw.adwin.setAmplitude(0)
        
        gw.adwin.setLocking(False)
        gw.adwin.setLockinAmplitude(0)
        gw.adwin.setLockinFrequency(73.3)

        m = gw.measure(f"{name}/{field_name}/{offset_name}")
        sleep(.5)
        m.start()
        sleep(3)
        m.stop()

        gw.adwin.setAmplitude(2) # 1 Volt to cross both critical currents, this sample needs even more
        gw.adwin.setPeriod(18.8679)

        m = gw.measure(f"{name}/{field_name}/{sweep_name}")

        sleep(.5)
        m.start()
        gw.adwin.setSweeping(True)
        gw.adwin.setOutput(True)
        sleep(30)
        m.stop()
        
        gw.adwin.setAmplitude(0)
        gw.adwin.setSweeping(False)
        gw.adwin.setOutput(False)
except:
    gw.adwin.setOutput(False)
    gw.magnet.goto_zero()


gw.adwin.setOutput(False)
gw.magnet.goto_zero()
# Out:
#  86%|████████▋ | 208/241 [3:46:17<35:56, 65.35s/it]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
