# %% [markdown]
# imports (check ivscripts.py)

# %%
# %load_ext autoreload
# %autoreload 2
from ivscript import BlueforsServer, MeasurementScript
import numpy as np
from time import sleep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# test ivscript measurement functions (4min)

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/test123456789.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 10000
    measurement_script.femto2_amp = 1000

    measurement_script.magnetic_field_study(
        magnetic_fields = np.linspace(-30, 30, 11),
        amplitude = 0.9,
        period = 1,
        sweep_time = 1,
        offset_time = .5,
        magnetic_field_name = None,
        ramp_cool_down = 1,
        meas_cool_down = .1,
        vna_power = None,
        vna_frequency = None,
                        )
    sleep(5)

    measurement_script.frequency_study(
        vna_frequencies=np.linspace(2,20,10),
        vna_power=-25,
        amplitude=.85,
        period=1,
        sweep_time=1,
        offset_time = .5,
        vna_frequencies_name = None,
        ramp_cool_down = None,
        meas_cool_down = .1,
        magnetic_field = None,
                            )
    sleep(5)

    for freq in [1, 5, 15]:
        measurement_script.power_study(
            vna_powers=np.linspace(-35,0,8),
            vna_frequency=freq,
            amplitude=.85,
            period=1,
            sweep_time=1,
            offset_time = .5,
            vna_powers_name = None,
            ramp_cool_down = None,
            meas_cool_down = .1,
            magnetic_field = None,
                                )    
        sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()
# Out:
# ...
# 100%|██████████| 8/8 [00:33<00:00,  4.21s/it]

# %% [markdown]
# Ready to measure ahead!

# %% [markdown]
# - breaking

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_10_S22_breaking_0.hdf5',
        S='22'
    )
    while True:
        sleep(.1)
except KeyboardInterrupt:
    bluefors_server.stop_server()

# %% [markdown]
# - full characterization @ 1.2G_0

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_10_PR22e9_1.2G_1.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 1000

    measurement_script.amplitude = 1
    measurement_script.period = 28.0327 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 30

    measurement_script.magnetic_field_study(
        magnetic_fields = np.linspace(-30, 30, 241),
        )
    sleep(5)

    for magnetic_field in [0, 5, 10, 20]:
        for power in [-25, -30]:
            measurement_script.frequency_study(
                vna_frequencies=np.linspace(.1,20,200),
                vna_power=power,
                magnetic_field=magnetic_field,
                )
            sleep(5)

        for frequency in [7.8, 15, 19.3]:
            measurement_script.power_study(
                vna_powers=np.linspace(-35,-10,51),
                vna_frequency=frequency,
                magnetic_field=magnetic_field,
                )    
            sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

# 1786m 32s equals 30h
# Out:
# ...
# 100%|██████████| 51/51 [32:27<00:00, 38.19s/it]

# %% [markdown]
# - single IV @ 0.025G_0

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_15_S22_breaking_0.hdf5',
        S='22'
    )
    while True:
        sleep(.1)
except KeyboardInterrupt:
    bluefors_server.stop_server()

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_15_S22_tunneljuntion_0.025G0_1.hdf5',
        S='22'
    )

    measurement_script = MeasurementScript()
    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 10000
    measurement_script.amplitude = .4
    measurement_script.period = 238.003 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 240
    
    measurement_script.single_IV()

except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

measurement_script.save_state()
bluefors_server.stop_server()

# %% [markdown]
# - full characterization @ 4.3G_0

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_15_S22_breaking_1.hdf5',
        S='22'
    )
    while True:
        sleep(.1)
except KeyboardInterrupt:
    bluefors_server.stop_server()

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_15_PR22e9_4.3G_1.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 100

    measurement_script.amplitude = 1.8
    measurement_script.period = 28.0327 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 30

    measurement_script.single_IV()
    sleep(5)

    measurement_script.magnetic_field_study(
        magnetic_fields = np.linspace(-30, 30, 241),
        )
    sleep(5)

    for magnetic_field in [0, 5, 10, 20]:
        for power in [-25, -30]:
            measurement_script.frequency_study(
                vna_frequencies=np.linspace(.1,20,200),
                vna_power=power,
                magnetic_field=magnetic_field,
                )
            sleep(5)

        for frequency in [7.8, 15, 19.3]:
            measurement_script.power_study(
                vna_powers=np.linspace(-35,-10,51),
                vna_frequency=frequency,
                magnetic_field=magnetic_field,
                )    
            sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

# 1787m 50.7s equals 30h
# Out:
# ...
# 100%|██████████| 51/51 [32:27<00:00, 38.18s/it]

# %%
from p5control import InstrumentServer, InstrumentGateway, DataGateway
from p5control.server.inserv import InstrumentServerError

from time import sleep
import numpy as np
from tqdm import tqdm

from core import ADwinGold2_v4, FemtoDLPVA100B, Keysight34461A_thermometer, AMI430, BlueForsAPI, Faulhaber, ZNB40, Rref
from core.drivers.keysightP5028A import KeysightP5028A # Keysight VNA

import logging
logger = logging.getLogger(__name__)
logging.basicConfig(
    filename='bluefors_server_script.log',
    level=logging.DEBUG,
    filemode='w', # overwrites logs every time this script is started
    format='%(asctime)s.%(msecs)03d %(levelname)-8s %(thread)6d %(name)-30s %(funcName)-20s %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
)

class BlueforsServer():
    def __init__(self):
        pass
    def start_server(
            self, 
            server_name = None,
            S = '22',
            ):
        
        
        if server_name is None:
            self.inserv = InstrumentServer()
        else:
            self.inserv = InstrumentServer(data_server_filename=server_name)

        """
        Add Devices
        """
        self.inserv._add('adwin', ADwinGold2_v4)
        self.inserv._add('femtos', FemtoDLPVA100B)
        self.inserv._add('R_ref', Rref, R_ref = 53000)

        self.inserv._add('bluefors', BlueForsAPI)
        self.inserv._add('motor', Faulhaber)
        self.inserv._add('magnet', AMI430, '192.168.1.103')
        self.inserv._add('thermo', Keysight34461A_thermometer, 'TCPIP0::192.168.1.111::INSTR')
        # self.inserv._add('vna', ZNB40, '192.168.1.104', case = 'time', S = S) # antenna=11, stripline=22
        self.inserv._add('vna', KeysightP5028A, S='22')
        
        self.inserv.start()  

    def stop_server(self):        
        self.inserv.stop()
        try:
            self.inserv._remove('femtos')
        except InstrumentServerError or KeyError:
            pass
        try:
            self.inserv._remove('motor')
        except InstrumentServerError or KeyError:
            pass
        try:
            self.inserv._remove('magnet')
        except InstrumentServerError or KeyError:
            pass
        try:
            self.inserv._remove('vna')
        except InstrumentServerError or KeyError:
            pass

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_17_PR22e9_KeysightVNA_3.6G_0.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 100

    measurement_script.amplitude = 1.8
    measurement_script.period = 28.0327 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 30

    measurement_script.single_IV()
    sleep(5)

    measurement_script.magnetic_field_study(
        magnetic_fields = np.linspace(-30, 30, 241),
        )
    sleep(5)

    for magnetic_field in [0, 5, 10]:
        for power in [-25, -30]:
            measurement_script.frequency_study(
                vna_frequencies=np.linspace(.1,20,200),
                vna_power=power,
                magnetic_field=magnetic_field,
                )
            sleep(5)

        for frequency in [7.8, 15, 19.3]:
            measurement_script.power_study(
                vna_powers=np.linspace(-35,-10,51),
                vna_frequency=frequency,
                magnetic_field=magnetic_field,
                )    
            sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

# 1381m equals 30h
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]Exception in thread Thread-9 (_status_measurement_thread):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\BlueFors\Documents\p5control\p5control\measure\status.py", line 148, in _status_measurement_thread
#     dgw.append(
#   File "C:\Users\BlueFors\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\rpyc\core\netref.py", line 240, in __call__
#     return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
# ...

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_15_PR22e9_KeysightVNA_4.3G_0.hdf5',
        S='22'
    )
    while True:
        sleep(.1)
except KeyboardInterrupt:
    bluefors_server.stop_server()

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_22_PR22e9_KeysightVNA_3.6G_1_amplitude_study.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 100

    measurement_script.amplitude = 1.8
    measurement_script.period = 28.0327 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 30

    measurement_script.single_IV()
    sleep(5)

    for magnetic_field in [0, 5, 10]:
        for power in [-30]:
            measurement_script.frequency_study(
                vna_frequencies=np.linspace(11,12,100),
                vna_power=power,
                magnetic_field=magnetic_field,
                )
            sleep(5)

        for frequency in [7.8, 15, 19.3, 11.1, 11.2, 11.3, 11.4, 11.5, 11.6, 11.7, 11.8, 11.9, 12]:
            measurement_script.amplitude_study(
                vna_amplitudes=np.linspace(.01,.1,91),
                vna_frequency=frequency,
                magnetic_field=magnetic_field,
                )    
            sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

# 2900m equals 48h 20m
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]Exception in thread Thread-30697 (_status_measurement_thread):
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\BlueFors\Documents\p5control\p5control\measure\status.py", line 148, in _status_measurement_thread
#     dgw.append(
#   File "C:\Users\BlueFors\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\rpyc\core\netref.py", line 240, in __call__
#     return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
# ...

# %%
# Bei allerletztem Powersewwp, VNA Kabel fürr eine minute gezogen..

# %%
try:
    bluefors_server = BlueforsServer()
    bluefors_server.start_server(
        server_name='.data/23_11_24_PR22e9_RSVNA_3.6G_0_amplitude_study_0.hdf5',
        S='22'
    )
    
    measurement_script = MeasurementScript()

    measurement_script.femto1_amp = 1000
    measurement_script.femto2_amp = 100

    measurement_script.amplitude = 1.8
    measurement_script.period = 28.0327 # equals 35.673mHz, 50Hz equals 25 ms
    measurement_script.sweep_time = 30

    measurement_script.single_IV()
    sleep(5)

    for magnetic_field in [0, 5, 10]:
        for power in [-30]:
            measurement_script.frequency_study(
                vna_frequencies=np.linspace(11,12,100),
                vna_power=power,
                magnetic_field=magnetic_field,
                )
            sleep(5)

        for frequency in [7.8, 15, 19.3, 11.1, 11.2, 11.3, 11.4, 11.5, 11.6, 11.7, 11.8, 11.9, 12]:
            measurement_script.amplitude_study(
                vna_amplitudes=np.linspace(.01,.1,91),
                vna_frequency=frequency,
                magnetic_field=magnetic_field,
                )    
            sleep(5)

    measurement_script.save_state()
    bluefors_server.stop_server()
except KeyboardInterrupt:
    measurement_script.save_state()
    bluefors_server.stop_server()

# 2900m equals 48h 20m
# Out:
# ...
# 100%|██████████| 91/91 [57:53<00:00, 38.17s/it]
