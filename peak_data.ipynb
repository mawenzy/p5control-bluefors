# %%
import matplotlib.pyplot as plt
import numpy as np

from p5control import DataGateway, InstrumentGateway

dgw = DataGateway()

dgw.connect()

# %%
dgw.close()

# %%
len(dgw.get("test").keys())
# Out:
# 66

# %%
plt.plot(dgw.get_data("test/62", field="V").T)
